# %%
device = 'cuda:2'

# %%
import torch
import time
from include import *
from tqdm.notebook import tqdm
import numpy as np

# %%
x = torch.randn(1,3,256,256).to(device)

# %%
model= Unet_Mixer_parallel().to(device)
#model= Unet().to(device)

# %%
T=[]
for i in tqdm(range(1000)):
    start = time.time()
    model(x)
    end = time.time()
    T.append(end-start)

# %%
np.mean(T)
# Out:
# 0.017457068681716918

# %%
T
# Out:
# [0.4514274597167969,
#  0.015999317169189453,
#  0.014996051788330078,
#  0.015289306640625,
#  0.015175342559814453,
#  0.015277385711669922,
#  0.015108823776245117,
#  0.01550912857055664,
#  0.017264127731323242,
#  0.016006946563720703,
#  0.015633106231689453,
#  0.015639305114746094,
#  0.015954971313476562,
#  0.016040325164794922,
#  0.01759171485900879,
#  0.018954992294311523,
#  0.018718719482421875,
#  0.01751708984375,
#  0.018082380294799805,
#  0.016621112823486328,
#  0.0162813663482666,
#  0.01602005958557129,
#  0.015845775604248047,
#  0.016269922256469727,
#  0.01731586456298828,
#  0.017375707626342773,
#  0.016812562942504883,
#  0.016876220703125,
#  0.015699386596679688,
#  0.014707326889038086,
#  0.014920473098754883,
#  0.015432596206665039,
#  0.014786720275878906,
#  0.015124082565307617,
#  0.016231536865234375,
#  0.01531362533569336,
#  0.014766216278076172,
#  0.014750003814697266,
#  0.01580023765563965,
#  0.015088796615600586,
# ...
