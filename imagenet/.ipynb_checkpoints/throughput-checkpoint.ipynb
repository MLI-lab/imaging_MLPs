# %%
device = 'cuda:3'

# %%
import torch
import time
from include import *
from tqdm.notebook import tqdm
import numpy as np

# %%
x = torch.randn(70,3,256,256).to(device)

# %%
model= Unet_Mixer().to(device)
#model= Unet().to(device)

# %%
T=[]
for i in tqdm(range(100)):
    start = time.time()
    model(x)
    end = time.time()
    T.append(end-start)

# %%
np.mean(T)
# Out:
# 0.1948751664161682

# %%
T
# Out:
# [0.01804351806640625,
#  0.01583242416381836,
#  0.0361325740814209,
#  0.19876718521118164,
#  0.19486641883850098,
#  0.1940746307373047,
#  0.1925053596496582,
#  0.19428491592407227,
#  0.19446730613708496,
#  0.19454145431518555,
#  0.3207414150238037,
#  0.1941695213317871,
#  0.1933588981628418,
#  0.1943364143371582,
#  0.19327950477600098,
#  0.1940312385559082,
#  0.1945335865020752,
#  0.19433283805847168,
#  0.19390439987182617,
#  0.19446659088134766,
#  0.19357824325561523,
#  0.19312667846679688,
#  0.19297337532043457,
#  0.1947920322418213,
#  0.1944572925567627,
#  0.19379520416259766,
#  0.19480586051940918,
#  0.19459033012390137,
#  0.19430184364318848,
#  0.19496417045593262,
#  0.19395136833190918,
#  0.19488215446472168,
#  0.19414591789245605,
#  0.19438409805297852,
#  0.2336268424987793,
#  0.2880690097808838,
#  0.19479775428771973,
#  0.1941688060760498,
#  0.19420886039733887,
#  0.19481897354125977,
#  0.19410181045532227,
#  0.19459843635559082,
# ...
